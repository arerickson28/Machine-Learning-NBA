# %%
import requests
import pandas as pd

# %%
nba_url = "https://www.balldontlie.io/api/v1/players"

# %%
response = requests.get(nba_url).json()
response
# Out:
# {'data': [{'id': 14,
#    'first_name': 'Ike',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Anigbogu',
#    'position': 'C',
#    'team': {'id': 12,
#     'abbreviation': 'IND',
#     'city': 'Indiana',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Indiana Pacers',
#     'name': 'Pacers'},
#    'weight_pounds': None},
#   {'id': 25,
#    'first_name': 'Ron',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Baker',
#    'position': 'G',
#    'team': {'id': 20,
#     'abbreviation': 'NYK',
#     'city': 'New York',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'New York Knicks',
#     'name': 'Knicks'},
#    'weight_pounds': None},
#   {'id': 47,
#    'first_name': 'Jabari',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Bird',
#    'position': 'G',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
# ...

# %%
test = response['data'][6]
test
# Out:
# {'id': 1,
#  'first_name': 'Alex',
#  'height_feet': 6,
#  'height_inches': 6,
#  'last_name': 'Abrines',
#  'position': 'G',
#  'team': {'id': 21,
#   'abbreviation': 'OKC',
#   'city': 'Oklahoma City',
#   'conference': 'West',
#   'division': 'Northwest',
#   'full_name': 'Oklahoma City Thunder',
#   'name': 'Thunder'},
#  'weight_pounds': 200}

# %%
nba_df_initial = pd.DataFrame(test)
nba_df_initial
# Out:
#               id first_name height_feet height_inches last_name position  \
# abbreviation  14        Ike        None          None  Anigbogu        C
# city          14        Ike        None          None  Anigbogu        C
# conference    14        Ike        None          None  Anigbogu        C
# division      14        Ike        None          None  Anigbogu        C
# full_name     14        Ike        None          None  Anigbogu        C
# id            14        Ike        None          None  Anigbogu        C
# name          14        Ike        None          None  Anigbogu        C
#
#                         team weight_pounds
# abbreviation             IND          None
# city                 Indiana          None
# conference              East          None
# division             Central          None
# full_name     Indiana Pacers          None
# id                        12          None
# name                  Pacers          None

# %%
player_id = test['id']
print(player_id)

team_info = test['team']
# print(team_info)
team_id = team_info['id']
print(team_id)
team_city = team_info['city']
print(team_city)
team_name = team_info['name']
print(team_name)

player_first_name = test['first_name']
player_last_name = test['last_name']
player_full_name = player_first_name + " " + player_last_name
print(player_full_name)

player_height_feet = test['height_feet']
player_height_inches = test['height_inches']
player_height = (player_height_feet*12) + (player_height_inches)

print(player_height)

player_weight = test['weight_pounds']
print(player_weight)
# Out:
# 1
# 21
# Oklahoma City
# Thunder
# Alex Abrines
# 78
# 200

# %%
my_nba_dictionary = {
    'player_id' : [player_id], 
    'player_name': [player_full_name], 
    'player_height_inches' : [player_height],
    'player_weight_pounds' : [player_weight],
    'player_team_city' : [team_city],
    'player_team_name': [team_name]}
                                    
                                    
                                    
my_nba_df = pd.DataFrame(my_nba_dictionary)
my_nba_df
# Out:
#    player_id   player_name  player_height_inches  player_weight_pounds  \
# 0          1  Alex Abrines                    78                   200
#
#   player_team_city player_team_name
# 0    Oklahoma City          Thunder

# %%
my_empty_df = pd.DataFrame()
my_empty_df['player_id'] = [player_id]
my_empty_df[ 'player_name'] = [player_full_name]
my_empty_df['player_height_inches'] = [player_height]
my_empty_df['player_weight_pounds'] = [player_weight]
my_empty_df['player_team_id'] = [team_id]
my_empty_df['player_team_city'] = [team_city]
my_empty_df['player_team_name'] = [team_name]

my_empty_df
# Out:
#    player_id   player_name  player_height_inches  player_weight_pounds  \
# 0          1  Alex Abrines                    78                   200
#
#   player_team_city player_team_name
# 0    Oklahoma City          Thunder

# %%
nba_data = response['data']
nba_data
# Out:
# [{'id': 14,
#   'first_name': 'Ike',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Anigbogu',
#   'position': 'C',
#   'team': {'id': 12,
#    'abbreviation': 'IND',
#    'city': 'Indiana',
#    'conference': 'East',
#    'division': 'Central',
#    'full_name': 'Indiana Pacers',
#    'name': 'Pacers'},
#   'weight_pounds': None},
#  {'id': 25,
#   'first_name': 'Ron',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Baker',
#   'position': 'G',
#   'team': {'id': 20,
#    'abbreviation': 'NYK',
#    'city': 'New York',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'New York Knicks',
#    'name': 'Knicks'},
#   'weight_pounds': None},
#  {'id': 47,
#   'first_name': 'Jabari',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Bird',
#   'position': 'G',
#   'team': {'id': 2,
#    'abbreviation': 'BOS',
#    'city': 'Boston',
#    'conference': 'East',
#    'division': 'Atlantic',
# ...

# %%
column_names = [
    'player_id', 
    'player_name', 
    'player_height_inches', 
    'player_weight_pounds', 
    'player_team_id',
    'player_team_city', 
    'player_team_name']

NBA_empty_df = pd.DataFrame(columns = column_names)


for player in nba_data :

       
        player_id = player['id']
#         print(player_id)
        NBA_empty_df.append({'player_id': player_id}, ignore_index=True)

    
        player_first_name = player['first_name']
        player_last_name = player['last_name']
        player_full_name = player_first_name + " " + player_last_name
#         print(player_full_name)
        NBA_empty_df.append({'player_name' : player_full_name}, ignore_index=True)
    
    
    
        player_height_feet = player['height_feet']
        player_height_inches = test['height_inches']
        
        if player_height_feet == None :
#             print("Null")
            NBA_empty_df.append({'player_height_inches': 'Null'}, ignore_index=True)
        else :
            player_height = (player_height_feet*12) + (player_height_inches)
#             print(player_height)
            NBA_empty_df.append({'player_height_inches': player_height}, ignore_index=True)

        player_weight = player['weight_pounds']
#         print(player_weight)
        NBA_empty_df.append({'player_weight_pounds': player_weight}, ignore_index=True)


        team_info = player['team']
        
        team_id = team_info['id']
#         print(team_id)
        NBA_empty_df.append({'player_team_id': team_id}, ignore_index=True)
    
    
        team_city = team_info['city']
#         print(team_city)
        NBA_empty_df.append({'player_team_city': team_city}, ignore_index=True)
    
        team_name = team_info['name']
#         print(team_name)
        NBA_empty_df.append({'player_team_name': team_name}, ignore_index=True)

    

       
        
     
#         NBA_empty_df['player_id'] = [player_id]
#         NBA_empty_df['player_name'] = [player_full_name]
#         NBA_empty_df['player_height_inches'] = [player_height]
#         NBA_empty_df['player_weight_pounds'] = [player_weight]
#         NBA_empty_df['player_team_id'] = [team_id]
#         NBA_empty_df['player_team_city'] = [team_city]
#         NBA_empty_df['player_team_name'] = [team_name]


        
        
NBA_empty_df
# Out:
# Empty DataFrame
# Columns: [player_id, player_name, player_height_inches, player_weight_pounds, player_team_id, player_team_city, player_team_name]
# Index: []

# %%
test_df = pd.DataFrame(columns = "player")

for player in nba_data :
    player_id = player['id']
    test_df.append({'player_id': player_id}, ignore_index=True)

test_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-899500b1dbde> in <module>
# ----> 1 test_df = pd.DataFrame(columns = "player")
#       2
#       3 for player in nba_data :
#       4     player_id = player['id']
#       5     test_df.append({'player_id': player_id}, ignore_index=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     219         from pandas.core.series import Series
#     220
# ...
