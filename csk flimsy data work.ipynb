# %%
# Dependencies
import pandas as pd
import requests

# %%
# Create file path for NBAPlayerAges.csv
nba_file = 'NBAPlayerAges.csv'

# read file with pandas
nba_df = pd.read_csv(nba_file)
nba_df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation  age  player_height  \
# 0           0      Dennis Rodman               CHI   36         198.12
# 1           1  Dwayne Schintzius               LAC   28         215.90
# 2           2       Earl Cureton               TOR   39         205.74
# 3           3        Ed O'Bannon               DAL   24         203.20
# 4           4        Ed Pinckney               MIA   34         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
#    ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# ...

# %%
# what do we have here
nba_df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
# Keeping specific columns and specific season only
nba_wanted_df = nba_df[['player_name', 'team_abbreviation', 'age','player_height', 'player_weight', 'season']]

nba_wanted_df = nba_wanted_df.loc[(nba_wanted_df['season'] == '2014-15') | (nba_wanted_df['season'] == '2015-16')
                                 | (nba_wanted_df['season'] == '2016-17') | (nba_wanted_df['season'] == '2017-18')
                                 | (nba_wanted_df['season'] == '2018-19') | (nba_wanted_df['season'] == '2019-20')]

# %%
nba_wanted_df
# Out:
#               player_name team_abbreviation  age  player_height  \
# 8107       Deron Williams               BKN   31         190.50
# 8108         Derrick Rose               CHI   26         190.50
# 8109      DeMarre Carroll               ATL   28         203.20
# 8110     DeMarcus Cousins               SAC   24         210.82
# 8111        DeMar DeRozan               TOR   25         200.66
# ...                   ...               ...  ...            ...
# 11140         Maxi Kleber               DAL   28         208.28
# 11141  Melvin Frazier Jr.               ORL   23         195.58
# 11142      Meyers Leonard               MIA   28         213.36
# 11143        Norvel Pelle               PHI   27         208.28
# 11144         Matt Thomas               TOR   25         193.04
#
#        player_weight   season
# 8107       90.718400  2014-15
# 8108       86.182480  2014-15
# 8109       96.161504  2014-15
# 8110      122.469840  2014-15
# 8111       99.790240  2014-15
# ...

# %%
# Bringing in allStats df
stats_file = 'allStatsFinal.csv'

# read file with pandas
stats_df = pd.read_csv(stats_file)

# %%
stats_df
# Out:
#         Unnamed: 0  gameID  statsID  assists  blocks  defensiveRebounds  \
# 0                0   27276   708256      1.0     0.0                4.0
# 1                1   27276   708257      1.0     0.0                3.0
# 2                2   27276   708258      2.0     3.0                2.0
# 3                3   27276   708259      1.0     0.0                3.0
# 4                4   27276   708260      1.0     0.0                3.0
# ...            ...     ...      ...      ...     ...                ...
# 166708      166708   62482  1446922      0.0     2.0                1.0
# 166709      166709   62482  1446924      1.0     0.0                0.0
# 166710      166710   62482  1446923      0.0     0.0                0.0
# 166711      166711   62482  1446925      0.0     0.0                0.0
# 166712      166712   62482  1446926      0.0     0.0                0.0
#
#         threePointFieldGoalPercent  threePointFieldGoalAttempted  \
# ...

# %%
stats_df.columns
# Out:
# Index(['Unnamed: 0', 'gameID', 'statsID', 'assists', 'blocks',
#        'defensiveRebounds', 'threePointFieldGoalPercent',
#        'threePointFieldGoalAttempted', 'threePointFieldGoal',
#        'fieldGoalPercent', 'fieldGoalAttempt', 'fieldGoalMade',
#        'freeThrowPercent', 'freeThrowAttempt', 'freeThrowMade', 'minutes',
#        'offensiveRebound', 'personalFouls', 'playerID', 'playerFirstName',
#        'playerHeightFeet', 'playerHeightInches', 'playerLastName',
#        'playerPosition', 'team_id', 'playerWeightPounds', 'points', 'rebounds',
#        'steals', 'teamID', 'turnovers'],
#       dtype='object')

# %%
# Combine first name and last name column into 1 for allStats
stats_df['playerName'] = stats_df['playerFirstName'] + ' ' + stats_df['playerLastName']

# %%
stats_df['playerName']
# Out:
# 0         Chandler Parsons
# 1            Dirk Nowitzki
# 2           Tyson Chandler
# 3              Monta Ellis
# 4            Jameer Nelson
#                 ...
# 166708         Jordan Bell
# 166709       Jonas Jerebko
# 166710         Jacob Evans
# 166711        Damian Jones
# 166712       Klay Thompson
# Name: playerName, Length: 166713, dtype: object

# %%
import datetime as dt

# %%
# Bringing in allGrame df
game_file = 'allGamesFinal.csv'

# read file with pandas
game_df = pd.read_csv(game_file)

# %%
game_df.dtypes

# %%
# Clean up date
game_df['date'] = game_df['date'].str.slice(0, 10)

# %%
game_df
# Out:
#       Unnamed: 0  gameID        date  homeTeamScore  visitorTeamScore  season  \
# 0              0   27276  2014-11-06            108                87    2014
# 1              1   27277  2014-11-07            122               119    2014
# 2              2   27278  2014-11-08             87                98    2014
# 3              3   27279  2014-11-09            116               100    2014
# 4              4   27280  2014-11-10             85                89    2014
# ...          ...     ...         ...            ...               ...     ...
# 6554        6554   62481  2019-06-02            104               109    2018
# 6555        6555   62350  2019-05-20            117               119    2018
# 6556        6556   62346  2019-05-16            114               111    2018
# 6557        6557   62485  2019-06-13            110               114    2018
# 6558        6558   62482  2019-06-05            109               123    2018
#
# ...

# %%
game_df
# Out:
#       Unnamed: 0  gameID                      date  homeTeamScore  \
# 0              0   27276  2014-11-06T00:00:00.000Z            108
# 1              1   27277  2014-11-07T00:00:00.000Z            122
# 2              2   27278  2014-11-08T00:00:00.000Z             87
# 3              3   27279  2014-11-09T00:00:00.000Z            116
# 4              4   27280  2014-11-10T00:00:00.000Z             85
# ...          ...     ...                       ...            ...
# 6554        6554   62481  2019-06-02T00:00:00.000Z            104
# 6555        6555   62350  2019-05-20T00:00:00.000Z            117
# 6556        6556   62346  2019-05-16T00:00:00.000Z            114
# 6557        6557   62485  2019-06-13T00:00:00.000Z            110
# 6558        6558   62482  2019-06-05T00:00:00.000Z            109
#
#       visitorTeamScore  season  period status   time  postseasonBoolean  ...  \
# 0                   87    2014       4  Final                     False  ...
# ...
