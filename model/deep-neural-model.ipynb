# %%
# Dependencies
import pandas as pd

# %%
# Load data
df = pd.read_csv('../data/machineLearningDataSet.csv')

# Drop the null columns where all values are null -- nothing to drop
df = df.dropna(axis='columns', how='all')

# Drop the null rows -- nothing to drop
df = df.dropna()

# Drop Unnamed: 0
df = df.drop(columns=['Unnamed: 0'])

df
# Out:
#        gameID  homeTeamID  visitorTeamID  homeTeamHeightAverage  \
# 0         1.0         2.0           23.0             199.390000
# 1         2.0        10.0           21.0             201.441538
# 2         3.0         4.0           17.0             201.050769
# 3         4.0         9.0            3.0             198.966667
# 4         5.0        12.0           15.0             199.683077
# ...       ...         ...            ...                    ...
# 6553  62481.0        28.0           10.0             198.901538
# 6554  62482.0        10.0           28.0             202.418462
# 6555  62483.0        10.0           28.0             201.832308
# 6556  62484.0        28.0           10.0             198.901538
# 6557  62485.0        10.0           28.0             201.832308
#
#       homeTeamWeightAverage  homeTeamAgeAverage  visitorTeamHeightAverage  \
# 0                102.625190           26.416667                200.269231
# 1                 97.906089           28.000000                199.878462
# 2                 99.301756           26.846154                201.050769
# 3                100.243832           27.466667                201.718333
# 4                 97.208255           26.461538                201.832308
# ...                     ...                 ...                       ...
# 6553              97.626955           27.923077                201.832308
# 6554             100.348507           28.692308                198.315385
# 6555              99.476215           28.615385                198.901538
# 6556              97.626955           27.923077                202.418462
# 6557              99.476215           28.615385                198.315385
#
#       visitorTeamWeightAverage  visitorTeamAgeAverage  homeTeamWin
# 0                    96.440638              25.153846          1.0
# 1                    97.696738              25.692308          1.0
# 2                   100.941666              26.692308          0.0
# 3                    98.656260              25.166667          1.0
# 4                    99.511106              27.692308          1.0
# ...                        ...                    ...          ...
# 6553                 99.476215              28.615385          0.0
# 6554                 97.975872              27.923077          0.0
# 6555                 98.952839              28.000000          0.0
# 6556                100.522966              29.230769          0.0
# 6557                 97.975872              27.923077          0.0
#
# [6558 rows x 10 columns]

# %%
# Assign X (data) and y (target)
drop_col = ['gameID', 'homeTeamID', 'visitorTeamID', 'homeTeamWin']
X = df.drop(drop_col, axis=1)
y = df['homeTeamWin']

y_names = ['Lose', 'Win']

print(X.shape, y.shape)
# Out:
# (6558, 6) (6558,)

# %%
# Split our data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
# Set up for deep learning model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create a Neural Network model 
model = Sequential()

model.add(Dense(units=20, activation='relu', input_dim=6))
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 20)                140
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 602
# Trainable params: 602
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 4918 samples
# Epoch 1/100
# 4918/4918 - 1s - loss: 0.6730 - accuracy: 0.5866
# Epoch 2/100
# 4918/4918 - 0s - loss: 0.6639 - accuracy: 0.5990
# Epoch 3/100
# 4918/4918 - 0s - loss: 0.6604 - accuracy: 0.6009
# Epoch 4/100
# 4918/4918 - 0s - loss: 0.6595 - accuracy: 0.6015
# Epoch 5/100
# 4918/4918 - 0s - loss: 0.6586 - accuracy: 0.6070
# Epoch 6/100
# 4918/4918 - 0s - loss: 0.6580 - accuracy: 0.6065
# Epoch 7/100
# 4918/4918 - 0s - loss: 0.6578 - accuracy: 0.6049
# Epoch 8/100
# 4918/4918 - 0s - loss: 0.6585 - accuracy: 0.6031
# Epoch 9/100
# 4918/4918 - 0s - loss: 0.6579 - accuracy: 0.6043
# Epoch 10/100
# 4918/4918 - 0s - loss: 0.6583 - accuracy: 0.6047
# Epoch 11/100
# 4918/4918 - 0s - loss: 0.6580 - accuracy: 0.6082
# Epoch 12/100
# 4918/4918 - 0s - loss: 0.6580 - accuracy: 0.6015
# Epoch 13/100
# 4918/4918 - 0s - loss: 0.6583 - accuracy: 0.6057
# Epoch 14/100
# 4918/4918 - 0s - loss: 0.6579 - accuracy: 0.6061
# Epoch 15/100
# 4918/4918 - 0s - loss: 0.6580 - accuracy: 0.6037
# Epoch 16/100
# 4918/4918 - 0s - loss: 0.6582 - accuracy: 0.6023
# Epoch 17/100
# 4918/4918 - 0s - loss: 0.6580 - accuracy: 0.6057
# Epoch 18/100
# 4918/4918 - 0s - loss: 0.6581 - accuracy: 0.5968
# Epoch 19/100
# 4918/4918 - 0s - loss: 0.6585 - accuracy: 0.6070
# Epoch 20/100
# 4918/4918 - 0s - loss: 0.6582 - accuracy: 0.6037
# Epoch 21/100
# 4918/4918 - 0s - loss: 0.6579 - accuracy: 0.6002
# Epoch 22/100
# 4918/4918 - 0s - loss: 0.6571 - accuracy: 0.6011
# Epoch 23/100
# 4918/4918 - 0s - loss: 0.6572 - accuracy: 0.6029
# Epoch 24/100
# 4918/4918 - 0s - loss: 0.6570 - accuracy: 0.6049
# Epoch 25/100
# 4918/4918 - 0s - loss: 0.6590 - accuracy: 0.5974
# Epoch 26/100
# 4918/4918 - 0s - loss: 0.6579 - accuracy: 0.6043
# Epoch 27/100
# 4918/4918 - 0s - loss: 0.6574 - accuracy: 0.6055
# Epoch 28/100
# 4918/4918 - 0s - loss: 0.6577 - accuracy: 0.6031
# Epoch 29/100
# 4918/4918 - 0s - loss: 0.6576 - accuracy: 0.6019
# Epoch 30/100
# 4918/4918 - 0s - loss: 0.6574 - accuracy: 0.6065
# Epoch 31/100
# 4918/4918 - 0s - loss: 0.6577 - accuracy: 0.6025
# Epoch 32/100
# 4918/4918 - 0s - loss: 0.6577 - accuracy: 0.6047
# Epoch 33/100
# 4918/4918 - 0s - loss: 0.6569 - accuracy: 0.6084
# Epoch 34/100
# 4918/4918 - 0s - loss: 0.6587 - accuracy: 0.6007
# Epoch 35/100
# 4918/4918 - 0s - loss: 0.6572 - accuracy: 0.6041
# Epoch 36/100
# 4918/4918 - 0s - loss: 0.6574 - accuracy: 0.6023
# Epoch 37/100
# 4918/4918 - 0s - loss: 0.6575 - accuracy: 0.6045
# Epoch 38/100
# 4918/4918 - 0s - loss: 0.6578 - accuracy: 0.6094
# Epoch 39/100
# 4918/4918 - 0s - loss: 0.6574 - accuracy: 0.6043
# Epoch 40/100
# 4918/4918 - 0s - loss: 0.6573 - accuracy: 0.6045
# Epoch 41/100
# 4918/4918 - 0s - loss: 0.6569 - accuracy: 0.6057
# Epoch 42/100
# 4918/4918 - 0s - loss: 0.6578 - accuracy: 0.6002
# Epoch 43/100
# 4918/4918 - 0s - loss: 0.6592 - accuracy: 0.5988
# Epoch 44/100
# 4918/4918 - 0s - loss: 0.6577 - accuracy: 0.6047
# Epoch 45/100
# 4918/4918 - 0s - loss: 0.6570 - accuracy: 0.6057
# Epoch 46/100
# 4918/4918 - 0s - loss: 0.6566 - accuracy: 0.6063
# Epoch 47/100
# 4918/4918 - 0s - loss: 0.6570 - accuracy: 0.6074
# Epoch 48/100
# 4918/4918 - 0s - loss: 0.6570 - accuracy: 0.6074
# Epoch 49/100
# 4918/4918 - 0s - loss: 0.6576 - accuracy: 0.6070
# Epoch 50/100
# 4918/4918 - 0s - loss: 0.6567 - accuracy: 0.6049
# Epoch 51/100
# 4918/4918 - 0s - loss: 0.6565 - accuracy: 0.6070
# Epoch 52/100
# 4918/4918 - 0s - loss: 0.6587 - accuracy: 0.6047
# Epoch 53/100
# 4918/4918 - 0s - loss: 0.6568 - accuracy: 0.6035
# Epoch 54/100
# 4918/4918 - 0s - loss: 0.6567 - accuracy: 0.6059
# Epoch 55/100
# 4918/4918 - 0s - loss: 0.6573 - accuracy: 0.6047
# Epoch 56/100
# 4918/4918 - 0s - loss: 0.6571 - accuracy: 0.6061
# Epoch 57/100
# 4918/4918 - 0s - loss: 0.6568 - accuracy: 0.6021
# Epoch 58/100
# 4918/4918 - 0s - loss: 0.6583 - accuracy: 0.6106
# Epoch 59/100
# 4918/4918 - 0s - loss: 0.6565 - accuracy: 0.6055
# Epoch 60/100
# 4918/4918 - 0s - loss: 0.6569 - accuracy: 0.6041
# Epoch 61/100
# 4918/4918 - 0s - loss: 0.6567 - accuracy: 0.6100
# Epoch 62/100
# 4918/4918 - 0s - loss: 0.6564 - accuracy: 0.6057
# Epoch 63/100
# 4918/4918 - 0s - loss: 0.6563 - accuracy: 0.6019
# Epoch 64/100
# 4918/4918 - 0s - loss: 0.6564 - accuracy: 0.6088
# Epoch 65/100
# 4918/4918 - 0s - loss: 0.6566 - accuracy: 0.6045
# Epoch 66/100
# 4918/4918 - 0s - loss: 0.6571 - accuracy: 0.6096
# Epoch 67/100
# 4918/4918 - 0s - loss: 0.6575 - accuracy: 0.6057
# Epoch 68/100
# 4918/4918 - 0s - loss: 0.6558 - accuracy: 0.6061
# Epoch 69/100
# 4918/4918 - 0s - loss: 0.6566 - accuracy: 0.6043
# Epoch 70/100
# 4918/4918 - 0s - loss: 0.6566 - accuracy: 0.6070
# Epoch 71/100
# 4918/4918 - 0s - loss: 0.6565 - accuracy: 0.6045
# Epoch 72/100
# 4918/4918 - 0s - loss: 0.6567 - accuracy: 0.6084
# Epoch 73/100
# 4918/4918 - 0s - loss: 0.6559 - accuracy: 0.6055
# Epoch 74/100
# 4918/4918 - 0s - loss: 0.6560 - accuracy: 0.6035
# Epoch 75/100
# 4918/4918 - 0s - loss: 0.6560 - accuracy: 0.6108
# Epoch 76/100
# 4918/4918 - 0s - loss: 0.6559 - accuracy: 0.6098
# Epoch 77/100
# 4918/4918 - 0s - loss: 0.6559 - accuracy: 0.6133
# Epoch 78/100
# 4918/4918 - 0s - loss: 0.6558 - accuracy: 0.6080
# Epoch 79/100
# 4918/4918 - 0s - loss: 0.6562 - accuracy: 0.6072
# Epoch 80/100
# 4918/4918 - 0s - loss: 0.6557 - accuracy: 0.6057
# Epoch 81/100
# 4918/4918 - 0s - loss: 0.6559 - accuracy: 0.6070
# Epoch 82/100
# 4918/4918 - 0s - loss: 0.6557 - accuracy: 0.6063
# Epoch 83/100
# 4918/4918 - 0s - loss: 0.6555 - accuracy: 0.6070
# Epoch 84/100
# 4918/4918 - 0s - loss: 0.6550 - accuracy: 0.6118
# Epoch 85/100
# 4918/4918 - 0s - loss: 0.6554 - accuracy: 0.6074
# Epoch 86/100
# 4918/4918 - 0s - loss: 0.6556 - accuracy: 0.6082
# Epoch 87/100
# 4918/4918 - 0s - loss: 0.6550 - accuracy: 0.6074
# Epoch 88/100
# 4918/4918 - 0s - loss: 0.6550 - accuracy: 0.6074
# Epoch 89/100
# 4918/4918 - 0s - loss: 0.6556 - accuracy: 0.6096
# Epoch 90/100
# 4918/4918 - 0s - loss: 0.6557 - accuracy: 0.6088
# Epoch 91/100
# 4918/4918 - 0s - loss: 0.6557 - accuracy: 0.6080
# Epoch 92/100
# 4918/4918 - 0s - loss: 0.6553 - accuracy: 0.6070
# Epoch 93/100
# 4918/4918 - 0s - loss: 0.6550 - accuracy: 0.6141
# Epoch 94/100
# 4918/4918 - 0s - loss: 0.6560 - accuracy: 0.6041
# Epoch 95/100
# 4918/4918 - 0s - loss: 0.6550 - accuracy: 0.6120
# Epoch 96/100
# 4918/4918 - 0s - loss: 0.6545 - accuracy: 0.6082
# Epoch 97/100
# 4918/4918 - 0s - loss: 0.6556 - accuracy: 0.6110
# Epoch 98/100
# 4918/4918 - 0s - loss: 0.6554 - accuracy: 0.6074
# Epoch 99/100
# 4918/4918 - 0s - loss: 0.6543 - accuracy: 0.6086
# Epoch 100/100
# 4918/4918 - 0s - loss: 0.6547 - accuracy: 0.6094

# %%
# Scoring model
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f'Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 1640/1640 - 0s - loss: 0.6744 - accuracy: 0.5933
# Deep Neural Network - Loss: 0.6743560471185823, Accuracy: 0.5932926535606384

# %%
# Save the model
model.save('deep_neural_model.h5')
