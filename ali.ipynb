# %%
import requests
import pandas as pd
import time

# %%
# Create empty dataframe
col_names = ['gameID', 'date', 'homeTeamScore', 'visitorTeamScore', 
             'season', 'period', 'status', 'time', 'postseasonBoolean', 
             'homeTeamID', 'homeTeamAbbrev', 'homeTeamCity', 'homeTeamConference', 
             'homeTeamDivision', 'homeTeamFullName', 'homeTeamName', 'visitorTeamID', 
             'visitorTeamAbbrev', 'visitorTeamCity', 'visitorTeamConference', 
             'visitorTeamDivision', 'visitorTeamFullName', 'visitorTeamName']
games_df = pd.DataFrame(columns=col_names)

# %%
# Get games for last 5 years
years = [2014, 2015, 2016, 2017, 2018]
for y in years:
    
    games_url_initial = f'https://www.balldontlie.io/api/v1/games?seasons[]={y}'
    data_initial = requests.get(games_url_initial).json()
    
    for page in range(1, data_initial['meta']['total_pages']+1):
        
        games_url = f'https://www.balldontlie.io/api/v1/games?seasons[]={y}&page={page}'
        data = requests.get(games_url).json()
        
        time.sleep(1)

        for game in data['data']:
            games_df.loc[len(games_df.index)] = [ game['id'], game['date'], game['home_team_score'], 
                                                 game['visitor_team_score'], game['season'], game['period'], 
                                                 game['status'], game['time'], game['postseason'], game['home_team']['id'],
                                                 game['home_team']['abbreviation'], game['home_team']['city'], game['home_team']['conference'], 
                                                 game['home_team']['division'], game['home_team']['full_name'], game['home_team']['name'], 
                                                 game['visitor_team']['id'], game['visitor_team']['abbreviation'], 
                                                 game['visitor_team']['city'], game['visitor_team']['conference'], 
                                                 game['visitor_team']['division'], game['visitor_team']['full_name'], 
                                                 game['visitor_team']['name'] ]

        
games_df.head(25)
# Out:
#    gameID                      date homeTeamScore visitorTeamScore season  \
# 0   27276  2014-11-06T00:00:00.000Z           108               87   2014
# 1   27277  2014-11-07T00:00:00.000Z           122              119   2014
# 2   27278  2014-11-08T00:00:00.000Z            87               98   2014
# 3   27279  2014-11-09T00:00:00.000Z           116              100   2014
# 4   27280  2014-11-10T00:00:00.000Z            85               89   2014
# 5   27281  2014-11-11T00:00:00.000Z           107              102   2014
# 6   27282  2014-11-12T00:00:00.000Z           107              103   2014
# 7   27283  2014-11-12T00:00:00.000Z           101              113   2014
# 8   27284  2014-11-13T00:00:00.000Z            93              100   2014
# 9   27285  2014-11-14T00:00:00.000Z           121              122   2014
# 10  27286  2014-11-15T00:00:00.000Z           120              107   2014
# 11  27287  2014-11-17T00:00:00.000Z           119               93   2014
# 12  27288  2014-11-19T00:00:00.000Z            86               88   2014
# 13  27289  2014-11-21T00:00:00.000Z            92              121   2014
# 14  27290  2015-04-07T00:00:00.000Z           105              100   2014
# 15  27291  2015-04-08T00:00:00.000Z            86              102   2014
# 16  27292  2015-04-10T00:00:00.000Z           103              104   2014
# 17  27293  2015-04-12T00:00:00.000Z           121              114   2014
# 18  27294  2015-04-13T00:00:00.000Z            97              107   2014
# 19  27295  2015-04-14T00:00:00.000Z           101              112   2014
# 20  27296  2015-04-15T00:00:00.000Z            92               87   2014
# 21  27297  2015-04-15T00:00:00.000Z           101              105   2014
# 22  27374  2014-11-13T00:00:00.000Z           111              110   2014
# 23  27375  2014-11-14T00:00:00.000Z            87              108   2014
# 24  27376  2014-11-15T00:00:00.000Z            90               99   2014
#
#    period status time postseasonBoolean homeTeamID  ... homeTeamDivision  \
# 0       4  Final                  False         25  ...        Northwest
# 1       4  Final                  False          4  ...        Southeast
# 2       4  Final                  False         11  ...        Southwest
# 3       4  Final                  False         25  ...        Northwest
# 4       4  Final                  False         13  ...          Pacific
# 5       4  Final                  False         15  ...        Southwest
# 6       4  Final                  False         30  ...        Southeast
# 7       4  Final                  False         18  ...        Northwest
# 8       4  Final                  False         28  ...         Atlantic
# 9       4  Final                  False          2  ...         Atlantic
# 10      4  Final                  False         13  ...          Pacific
# 11      4  Final                  False         15  ...        Southwest
# 12      4  Final                  False          9  ...          Central
# 13      4  Final                  False         18  ...        Northwest
# 14      4  Final                  False         16  ...        Southeast
# 15      4  Final                  False         20  ...         Atlantic
# 16      4  Final                  False         11  ...        Southwest
# 17      4  Final                  False         11  ...        Southwest
# 18      4  Final                  False         23  ...         Atlantic
# 19      4  Final                  False         24  ...          Pacific
# 20      4  Final                  False         28  ...         Atlantic
# 21      4  Final                  False         23  ...         Atlantic
# 22      4  Final                  False         15  ...        Southwest
# 23      4  Final                  False         12  ...          Central
# 24      4  Final                  False          5  ...          Central
#
#           homeTeamFullName   homeTeamName visitorTeamID visitorTeamAbbrev  \
# 0   Portland Trail Blazers  Trail Blazers             7               DAL
# 1        Charlotte Hornets        Hornets             1               ATL
# 2          Houston Rockets        Rockets            10               GSW
# 3   Portland Trail Blazers  Trail Blazers             8               DEN
# 4              LA Clippers       Clippers            27               SAS
# 5        Memphis Grizzlies      Grizzlies            14               LAL
# 6       Washington Wizards        Wizards             9               DET
# 7   Minnesota Timberwolves   Timberwolves            11               HOU
# 8          Toronto Raptors        Raptors             5               CHI
# 9           Boston Celtics        Celtics             6               CLE
# 10             LA Clippers       Clippers            24               PHX
# 11       Memphis Grizzlies      Grizzlies            11               HOU
# 12         Detroit Pistons        Pistons            24               PHX
# 13  Minnesota Timberwolves   Timberwolves            27               SAS
# 14              Miami Heat           Heat             4               CHA
# 15         New York Knicks         Knicks            12               IND
# 16         Houston Rockets        Rockets            27               SAS
# 17         Houston Rockets        Rockets            19               NOP
# 18      Philadelphia 76ers          76ers            17               MIL
# 19            Phoenix Suns           Suns            13               LAC
# 20         Toronto Raptors        Raptors             4               CHA
# 21      Philadelphia 76ers          76ers            16               MIA
# 22       Memphis Grizzlies      Grizzlies            26               SAC
# 23          Indiana Pacers         Pacers             8               DEN
# 24           Chicago Bulls          Bulls            12               IND
#
#    visitorTeamCity visitorTeamConference visitorTeamDivision  \
# 0           Dallas                  West           Southwest
# 1          Atlanta                  East           Southeast
# 2     Golden State                  West             Pacific
# 3           Denver                  West           Northwest
# 4      San Antonio                  West           Southwest
# 5      Los Angeles                  West             Pacific
# 6          Detroit                  East             Central
# 7          Houston                  West           Southwest
# 8          Chicago                  East             Central
# 9        Cleveland                  East             Central
# 10         Phoenix                  West             Pacific
# 11         Houston                  West           Southwest
# 12         Phoenix                  West             Pacific
# 13     San Antonio                  West           Southwest
# 14       Charlotte                  East           Southeast
# 15         Indiana                  East             Central
# 16     San Antonio                  West           Southwest
# 17     New Orleans                  West           Southwest
# 18       Milwaukee                  East             Central
# 19              LA                  West             Pacific
# 20       Charlotte                  East           Southeast
# 21           Miami                  East           Southeast
# 22      Sacramento                  West             Pacific
# 23          Denver                  West           Northwest
# 24         Indiana                  East             Central
#
#       visitorTeamFullName visitorTeamName
# 0        Dallas Mavericks       Mavericks
# 1           Atlanta Hawks           Hawks
# 2   Golden State Warriors        Warriors
# 3          Denver Nuggets         Nuggets
# 4       San Antonio Spurs           Spurs
# 5      Los Angeles Lakers          Lakers
# 6         Detroit Pistons         Pistons
# 7         Houston Rockets         Rockets
# 8           Chicago Bulls           Bulls
# 9     Cleveland Cavaliers       Cavaliers
# 10           Phoenix Suns            Suns
# 11        Houston Rockets         Rockets
# 12           Phoenix Suns            Suns
# 13      San Antonio Spurs           Spurs
# 14      Charlotte Hornets         Hornets
# 15         Indiana Pacers          Pacers
# 16      San Antonio Spurs           Spurs
# 17   New Orleans Pelicans        Pelicans
# 18        Milwaukee Bucks           Bucks
# 19            LA Clippers        Clippers
# 20      Charlotte Hornets         Hornets
# 21             Miami Heat            Heat
# 22       Sacramento Kings           Kings
# 23         Denver Nuggets         Nuggets
# 24         Indiana Pacers          Pacers
#
# [25 rows x 23 columns]

# %%
games_df.shape
# Out:
# (6559, 23)

# %%
games_df.to_csv('allGamesFinal.csv')

# %% [markdown]
# ## GAME STAT DATA

# %%
# Get player data for each player in all of the games in the dataframe above
col_names2 = ["gameID", "statsID", "assists", "blocks", "defensiveRebounds", "threePointFieldGoalPercent", 
              "threePointFieldGoalAttempted", "threePointFieldGoal", "fieldGoalPercent", "fieldGoalAttempt", 
              "fieldGoalMade", "freeThrowPercent", "freeThrowAttempt", 
              "freeThrowMade", "minutes", "offensiveRebound", "personalFouls", "playerID", "playerFirstName", 
              "playerHeightFeet", "playerHeightInches", "playerLastName", 
              "playerPosition", "team_id", "playerWeightPounds", "points", 
              "rebounds", "steals", "teamID", "turnovers"]

game_stats_df = pd.DataFrame(columns=col_names2)

# %%
game_stats_df.shape
# len(game_id_list)
# Out:
# (0, 30)

# %%
# Gather data from API
game_id_list = games_df['gameID']

for id in game_id_list[6444:]:
    print(f'Game id: {id}')
    #player_url_initial = f'https://www.balldontlie.io/api/v1/stats?game_ids[]={id}&per_page=100'
    #player_data_initial = requests.get(player_url_initial).json()
    
    for page in range(1,2):
        print(f'Page: {page}')
        player_games_url = f'https://www.balldontlie.io/api/v1/stats?game_ids[]={id}&page={page}&per_page=100'
        player_data = requests.get(player_games_url).json()
        print(len(player_data['data']))
        
        time.sleep(1)

        for stat in player_data['data']:
            game_stats_df.loc[len(game_stats_df.index)] = [ id, stat['id'], stat['ast'], stat['blk'],
                                                          stat['dreb'], stat['fg3_pct'], stat['fg3a'],
                                                          stat['fg3m'], stat['fg_pct'], stat['fga'],
                                                          stat['fgm'], stat['ft_pct'], stat['fta'],
                                                          stat['ftm'], stat['min'], stat['oreb'],
                                                          stat['pf'], stat['player']['id'], stat['player']['first_name'],
                                                          stat['player']['height_feet'], stat['player']['height_inches'],
                                                          stat['player']['last_name'], stat['player']['position'],
                                                          stat['player']['team_id'], stat['player']['weight_pounds'],
                                                          stat['pts'], stat['reb'], stat['stl'], stat['team']['id'],
                                                          stat['turnover'] ]
        print(f'Finished stats on page {page}')

print(f'Shape: {game_stats_df.shape}')  
game_stats_df.head(50)
# Out:
# Game id: 48815
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48814
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48816
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48813
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48830
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48843
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48880
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48888
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48895
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48889
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48899
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48892
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48891
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48893
# Page: 1
# 23
# Finished stats on page 1
# Game id: 48901
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48905
# Page: 1
# 23
# Finished stats on page 1
# Game id: 48914
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48908
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48906
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48927
# Page: 1
# 24
# Finished stats on page 1
# Game id: 48971
# Page: 1
# 25
# Finished stats on page 1
# Game id: 48989
# Page: 1
# 26
# Finished stats on page 1
# Game id: 48994
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49016
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49038
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49039
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60517
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60500
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60499
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60498
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60504
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60506
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60505
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60485
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60486
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60487
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60488
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49063
# Page: 1
# 25
# Finished stats on page 1
# Game id: 49066
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60489
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60491
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60490
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60492
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60493
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60494
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60496
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60497
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49127
# Page: 1
# 24
# Finished stats on page 1
# Game id: 49128
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60495
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60511
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60514
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60513
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60512
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60516
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60515
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49148
# Page: 1
# 24
# Finished stats on page 1
# Game id: 49153
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49103
# Page: 1
# 26
# Finished stats on page 1
# Game id: 49106
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60501
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60503
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60502
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60509
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60508
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60510
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60507
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60521
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60531
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60522
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60526
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60534
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61746
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60519
# Page: 1
# 25
# Finished stats on page 1
# Game id: 60520
# Page: 1
# 26
# Finished stats on page 1
# Game id: 60518
# Page: 1
# 25
# Finished stats on page 1
# Game id: 61741
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61740
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61743
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61744
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61739
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61742
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61745
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61723
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61724
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61725
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61726
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61727
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61728
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61736
# Page: 1
# 25
# Finished stats on page 1
# Game id: 61737
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61738
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61848
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61851
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62351
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62347
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61854
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61867
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61749
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61858
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62353
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62355
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62348
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62483
# Page: 1
# 26
# Finished stats on page 1
# Game id: 61861
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62344
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62480
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62484
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62345
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62349
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62481
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62350
# Page: 1
# 25
# Finished stats on page 1
# Game id: 62346
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62485
# Page: 1
# 26
# Finished stats on page 1
# Game id: 62482
# Page: 1
# 26
# Finished stats on page 1
# Shape: (166713, 30)
#    gameID statsID assists blocks defensiveRebounds threePointFieldGoalPercent  \
# 0   27276  708256       1      0                 4                          0
# 1   27276  708257       1      0                 3                      0.286
# 2   27276  708258       2      3                 2                          0
# 3   27276  708259       1      0                 3                          0
# 4   27276  708260       1      0                 3                        0.4
# 5   27276  708261       4      0                 2                          0
# 6   27276  708262       1      0                 1                          0
# 7   27276  708263       0      1                 3                          1
# 8   27276  708264       2      0                 2                          0
# 9   27276  708265       0      0                 1                          0
# 10  27276  708266       1      0                 1                          0
# 11  27276  708267       0      0                 0                          0
# 12  27276  708268       0      0                 1                          0
# 13  27276  708269       9      1                 7                      0.333
# 14  27276  708270       0      0                 5                          0
# 15  27276  708271       0      3                 4                          0
# 16  27276  708272       0      0                 4                        0.4
# 17  27276  708273       6      0                 5                      0.167
# 18  27276  708274       3      0                 2                        0.5
# 19  27276  708275       0      1                 4                          0
# 20  27276  708276       3      0                 0                          0
# 21  27276  708277       3      1                 2                       0.75
# 22  27276  708278       0      0                 3                          0
# 23  27276  708279       0      0                 0                          0
# 24  27276  708280       0      0                 3                          1
# 25  27276  708281       1      0                 2                        0.5
# 26  27277  709512       2      0                 2                        0.5
# 27  27277  709513       3      0                 5                      0.333
# 28  27277  709514       2      1                 8                          0
# 29  27277  709515       1      1                 2                      0.571
# 30  27277  709516      15      1                 2                       0.25
# 31  27277  709517       3      0                 2                        0.4
# 32  27277  709518       1      0                 8                          0
# 33  27277  709519       0      0                 0                          0
# 34  27277  709520       1      0                 1                          0
# 35  27277  709521       0      0                 1                      0.286
# 36  27277  709522       0      0                 0                          0
# 37  27277  709523    None   None              None                       None
# 38  27277  709524    None   None              None                       None
# 39  27277  709525       2      1                 2                          0
# 40  27277  709526       1      0                 2                       0.25
# 41  27277  709527       3      2                 6                          0
# 42  27277  709528       4      0                11                      0.333
# 43  27277  709529      10      2                 8                          0
# 44  27277  709530       2      0                 2                       0.25
# 45  27277  709531       2      2                 4                          0
# 46  27277  709532       0      0                 2                          0
# 47  27277  709533       2      0                 3                        0.6
# 48  27277  709534       5      0                 0                          0
# 49  27277  709535    None   None              None                       None
#
#    threePointFieldGoalAttempted threePointFieldGoal fieldGoalPercent  \
# 0                             3                   0            0.385
# 1                             7                   2            0.353
# 2                             0                   0                0
# 3                             1                   0            0.462
# 4                             5                   2            0.222
# 5                             2                   0            0.286
# 6                             0                   0              0.6
# 7                             1                   1              0.5
# 8                             2                   0            0.375
# 9                             1                   0              0.2
# 10                            0                   0                0
# 11                            0                   0                1
# 12                            1                   0              0.5
# 13                            6                   2             0.25
# 14                            1                   0            0.625
# 15                            0                   0              0.5
# 16                            5                   2              0.5
# 17                            6                   1            0.462
# 18                            4                   2              0.6
# 19                            0                   0                1
# 20                            1                   0                0
# 21                            4                   3              0.5
# 22                            0                   0              0.5
# 23                            0                   0                0
# 24                            1                   1                1
# 25                            2                   1            0.333
# 26                            6                   3            0.571
# 27                            3                   1            0.364
# 28                            0                   0            0.688
# 29                            7                   4              0.5
# 30                            4                   1            0.391
# 31                            5                   2            0.429
# 32                            1                   0              0.2
# 33                            0                   0                0
# 34                            0                   0             0.75
# 35                            7                   2             0.25
# 36                            0                   0                0
# 37                         None                None             None
# 38                         None                None             None
# 39                            0                   0            0.667
# 40                            4                   1            0.286
# 41                            0                   0            0.625
# 42                            3                   1            0.467
# 43                            4                   0            0.375
# 44                            4                   1             0.25
# 45                            0                   0            0.625
# 46                            0                   0                1
# 47                            5                   3            0.545
# 48                            1                   0                0
# 49                         None                None             None
#
#    fieldGoalAttempt  ... playerHeightInches  playerLastName playerPosition  \
# 0                13  ...                 10         Parsons              F
# 1                17  ...                  0        Nowitzki              F
# 2                 2  ...                  1        Chandler              C
# 3                13  ...               None           Ellis
# 4                 9  ...               None          Nelson
# 5                 7  ...                  3          Harris              G
# 6                 5  ...               None          Wright
# 7                 6  ...                  9           Aminu              F
# 8                 8  ...                  0           Barea              G
# 9                 5  ...               None       Jefferson
# 10                2  ...                  6         Crowder              F
# 11                1  ...               None           Smith
# 12                2  ...               None      Villanueva
# 13                8  ...                  8           Batum            F-G
# 14               16  ...                 11        Aldridge              F
# 15                6  ...                  0           Lopez              C
# 16                6  ...               None        Matthews            G-F
# 17               13  ...                  3         Lillard              G
# 18                5  ...               None           Blake
# 19                6  ...               None           Kaman
# 20                3  ...                  6          Barton              G
# 21                8  ...                  3        McCollum              G
# 22                2  ...               None        Robinson
# 23                0  ...               None        Freeland
# 24                1  ...                  1         Leonard            F-C
# 25                3  ...               None          Wright
# 26                7  ...                  8         Carroll              F
# 27               11  ...                  8         Millsap              F
# 28               16  ...                 10         Horford            C-F
# 29               12  ...                  7          Korver            G-F
# 30               23  ...                  2          Teague              G
# 31                7  ...               None           Antic
# 32                5  ...                  7       Sefolosha              F
# 33                0  ...               None            Mack              G
# 34                4  ...                  1        Schroder              G
# 35                8  ...                  8           Scott              F
# 36                0  ...                  5        Bazemore              G
# 37             None  ...               None           Brand              F
# 38             None  ...                 11         Muscala            F-C
# 39                6  ...                  7  Kidd-Gilchrist              F
# 40                7  ...                  9        Williams              F
# 41               24  ...               None       Jefferson
# 42               15  ...                  6      Stephenson              G
# 43               16  ...                  1          Walker              G
# 44                4  ...               None        Hairston
# 45                8  ...                  0          Zeller              C
# 46                2  ...               None         Maxiell
# 47               11  ...               None            Neal
# 48                4  ...               None         Roberts
# 49             None  ...                  9         Biyombo              C
#
#    team_id playerWeightPounds points rebounds steals teamID turnovers
# 0        1                230     11        4      0      7         1
# 1        7                245     17        3      0      7         2
# 2       11                240      4        3      0      7         1
# 3       10               None     14        3      1      7         2
# 4       22               None      6        4      0      7         1
# 5        7                185      7        3      1      7         0
# 6       10               None      6        3      0      7         0
# 7       22                220      7        5      2      7         0
# 8        7                185      8        2      2      7         0
# 9        3               None      3        2      0      7         0
# 10      16                235      0        1      0      7         0
# 11      11               None      2        0      0      7         0
# 12      28               None      2        1      0      7         0
# 13       4                200      8        9      0     25         2
# 14      27                260     20        7      0     25         1
# 15      17                275      8        8      0     25         2
# 16      17               None     12        4      1     25         2
# 17      25                195     18        5      1     25         5
# 18      30               None      8        2      0     25         0
# 19      13               None     12        5      0     25         1
# 20       8                190      0        0      0     25         2
# 21      25                190     13        2      0     25         0
# 22      26               None      3        4      1     25         2
# 23      25               None      0        1      0     25         0
# 24      16                255      3        3      0     25         0
# 25      16               None      3        3      0     25         0
# 26      11                215     13        4      1      1         2
# 27       8                246     13        6      1      1         6
# 28      23                245     24       10      3      1         1
# 29      17                212     20        2      0      1         2
# 30       1                195     22        4      0      1         5
# 31       1               None      8        2      1      1         0
# 32      11                220      3        8      0      1         1
# 33       4               None      0        0      0      1         0
# 34      21                172     10        1      2      1         0
# 35      23                237      6        1      0      1         2
# 36      26                201      0        0      0      1         0
# 37       5               None   None     None   None      1      None
# 38      21                240   None     None   None      1      None
# 39       7                232     10        4      0      4         3
# 40      17                237      5        2      1      4         1
# 41       2               None     34        9      1      4         1
# 42      14                230     17       13      0      4         4
# 43       2                184     15        9      3      4         2
# 44       4               None      4        3      0      4         2
# 45       4                240     10        5      1      4         3
# 46       9               None      4        2      0      4         1
# 47      27               None     23        4      0      4         1
# 48      19               None      0        0      0      4         1
# 49       4                255   None     None   None      4      None
#
# [50 rows x 30 columns]

# %%
#48787, 49061, 48826, 48835, 49071, 48801, 48809 - incomplete data due to weird exception
#game_stats_df.tail(25)
game_stats_df.shape
# Out:
# (166713, 30)

# %%
game_stats_df.to_csv('allStatsFinal.csv')

# %% [markdown]
# # MORE ETL

# %% [markdown]
# ## Add winner/loser column

# %% [markdown]
# ## Combine all relevant data to one master dataframe

# %%
# Load existing CSVs if necessary:
#game_df = pd.read_csv('allGamesFinal.csv')
#game_stats_df = pd.read_csv('allStatsFinal.csv')
