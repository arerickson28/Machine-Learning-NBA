# %%
import requests
import pandas as pd
url = 'https://www.balldontlie.io/#get-all-players'

# %%
# Create empty dataframe
col_names = ['gameID', 'date', 'homeTeamScore', 'visitorTeamScore', 
             'season', 'period', 'status', 'time', 'postseasonBoolean', 
             'homeTeamID', 'homeTeamAbbrev', 'homeTeamCity', 'homeTeamConference', 
             'homeTeamDivision', 'homeTeamFullName', 'homeTeamName', 'visitorTeamID', 
             'visitorTeamAbbrev', 'visitorTeamCity', 'visitorTeamConference', 
             'visitorTeamDivision', 'visitorTeamFullName', 'visitorTeamName']
games_df = pd.DataFrame(columns=col_names)

# %%
# Get games for last 5 years
#games_url = f'https://www.balldontlie.io/api/v1/games?seasons[]={year}'
years = [2014]#, 2015, 2016, 2017, 2018]
for y in years:
    year = y
    games_url = f'https://www.balldontlie.io/api/v1/games?seasons[]={year}'
    data = requests.get(games_url).json()
    print(data)
    for game in data['data']:
        games_df.loc[len(games_df.index)] = [ game['id'], game['date'], game['home_team_score'], 
                                             game['visitor_team_score'], game['season'], game['period'], 
                                             game['status'], game['time'], game['postseason'], game['home_team']['id'],
                                             game['home_team']['abbreviation'], game['home_team']['city'], game['home_team']['conference'], 
                                             game['home_team']['division'], game['home_team']['full_name'], game['home_team']['name'], 
                                             game['visitor_team']['id'], game['visitor_team']['abbreviation'], 
                                             game['visitor_team']['city'], game['visitor_team']['conference'], 
                                             game['visitor_team']['division'], game['visitor_team']['full_name'], 
                                             game['visitor_team']['name'] ]
#         games_df['gameID'] = game['id']
#         games_df['date'] = game['date']
#         games_df['homeTeamScore'] = game['home_team_score']
#         games_df['visitorTeamScore'] = game['visitor_team_score']
#         games_df['season'] = game['season']
#         games_df['period'] = game['period']
#         games_df['status'] = game['status']
#         games_df['time'] = game['time']
#         games_df['postseasonBoolean'] = game['postseason']
#         games_df['homeTeamID'] = game['home_team']['id']
#         games_df['homeTeamAbbrev'] = game['home_team']['abbreviation']
#         games_df['homeTeamCity'] = game['home_team']['city']
#         games_df['homeTeamConference'] = game['home_team']['conference']
#         games_df['homeTeamDivision'] = game['home_team']['division']
#         games_df['homeTeamFullName'] = game['home_team']['full_name']
#         games_df['homeTeamName'] = game['home_team']['name']
#         games_df['visitorTeamID'] = game['visitor_team']['id']
#         games_df['visitorTeamAbbrev'] = game['visitor_team']['abbreviation']
#         games_df['visitorTeamCity'] = game['visitor_team']['city']
#         games_df['visitorTeamConference'] = game['visitor_team']['conference']
#         games_df['visitorTeamDivision'] = game['visitor_team']['division']
#         games_df['visitorTeamFullName'] = game['visitor_team']['full_name']
#         games_df['visitorTeamName'] = game['visitor_team']['name']
        
games_df.head()
# Get player data for each player in last 5 years
# Put all into CSV
# Grab ages from the existing CSV
# Out:
# {'data': [{'id': 27276, 'date': '2014-11-06T00:00:00.000Z', 'home_team': {'id': 25, 'abbreviation': 'POR', 'city': 'Portland', 'conference': 'West', 'division': 'Northwest', 'full_name': 'Portland Trail Blazers', 'name': 'Trail Blazers'}, 'home_team_score': 108, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 7, 'abbreviation': 'DAL', 'city': 'Dallas', 'conference': 'West', 'division': 'Southwest', 'full_name': 'Dallas Mavericks', 'name': 'Mavericks'}, 'visitor_team_score': 87}, {'id': 27277, 'date': '2014-11-07T00:00:00.000Z', 'home_team': {'id': 4, 'abbreviation': 'CHA', 'city': 'Charlotte', 'conference': 'East', 'division': 'Southeast', 'full_name': 'Charlotte Hornets', 'name': 'Hornets'}, 'home_team_score': 122, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 1, 'abbreviation': 'ATL', 'city': 'Atlanta', 'conference': 'East', 'division': 'Southeast', 'full_name': 'Atlanta Hawks', 'name': 'Hawks'}, 'visitor_team_score': 119}, {'id': 27278, 'date': '2014-11-08T00:00:00.000Z', 'home_team': {'id': 11, 'abbreviation': 'HOU', 'city': 'Houston', 'conference': 'West', 'division': 'Southwest', 'full_name': 'Houston Rockets', 'name': 'Rockets'}, 'home_team_score': 87, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 10, 'abbreviation': 'GSW', 'city': 'Golden State', 'conference': 'West', 'division': 'Pacific', 'full_name': 'Golden State Warriors', 'name': 'Warriors'}, 'visitor_team_score': 98}, {'id': 27279, 'date': '2014-11-09T00:00:00.000Z', 'home_team': {'id': 25, 'abbreviation': 'POR', 'city': 'Portland', 'conference': 'West', 'division': 'Northwest', 'full_name': 'Portland Trail Blazers', 'name': 'Trail Blazers'}, 'home_team_score': 116, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 8, 'abbreviation': 'DEN', 'city': 'Denver', 'conference': 'West', 'division': 'Northwest', 'full_name': 'Denver Nuggets', 'name': 'Nuggets'}, 'visitor_team_score': 100}, {'id': 27280, 'date': '2014-11-10T00:00:00.000Z', 'home_team': {'id': 13, 'abbreviation': 'LAC', 'city': 'LA', 'conference': 'West', 'division': 'Pacific', 'full_name': 'LA Clippers', 'name': 'Clippers'}, 'home_team_score': 85, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 27, 'abbreviation': 'SAS', 'city': 'San Antonio', 'conference': 'West', 'division': 'Southwest', 'full_name': 'San Antonio Spurs', 'name': 'Spurs'}, 'visitor_team_score': 89}, {'id': 27281, 'date': '2014-11-11T00:00:00.000Z', 'home_team': {'id': 15, 'abbreviation': 'MEM', 'city': 'Memphis', 'conference': 'West', 'division': 'Southwest', 'full_name': 'Memphis Grizzlies', 'name': 'Grizzlies'}, 'home_team_score': 107, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 14, 'abbreviation': 'LAL', 'city': 'Los Angeles', 'conference': 'West', 'division': 'Pacific', 'full_name': 'Los Angeles Lakers', 'name': 'Lakers'}, 'visitor_team_score': 102}, {'id': 27282, 'date': '2014-11-12T00:00:00.000Z', 'home_team': {'id': 30, 'abbreviation': 'WAS', 'city': 'Washington', 'conference': 'East', 'division': 'Southeast', 'full_name': 'Washington Wizards', 'name': 'Wizards'}, 'home_team_score': 107, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'visitor_team': {'id': 9, 'abbreviation': 'DET', 'city': 'Detroit', 'conference': 'East', 'division': 'Central', 'full_name': 'Detroit Pistons', 'name': 'Pistons'}, 'visitor_team_score': 103}, {'id': 27283, 'date': '2014-11-12T00:00:00.000Z', 'home_team': {'id': 18, 'abbreviation': 'MIN', 'city': 'Minnesota', 'conference': 'West', 'division': 'Northwest', 'full_name': 'Minnesota Timberwolves', 'name': 'Timberwolves'}, 'home_team_score': 101, 'period': 4, 'postseason': False, 'season': 2014, 'status': 'Final', 'time': ' ', 'v ...
#    gameID                      date  homeTeamScore  visitorTeamScore  season  \
# 0   27276  2014-11-06T00:00:00.000Z            108                87    2014
# 1   27277  2014-11-07T00:00:00.000Z            122               119    2014
# 2   27278  2014-11-08T00:00:00.000Z             87                98    2014
# 3   27279  2014-11-09T00:00:00.000Z            116               100    2014
# 4   27280  2014-11-10T00:00:00.000Z             85                89    2014
#
#    period status time  postseasonBoolean  homeTeamID  ... homeTeamDivision  \
# 0       4  Final                   False          25  ...        Northwest
# 1       4  Final                   False           4  ...        Southeast
# 2       4  Final                   False          11  ...        Southwest
# 3       4  Final                   False          25  ...        Northwest
# 4       4  Final                   False          13  ...          Pacific
#
#          homeTeamFullName   homeTeamName visitorTeamID visitorTeamAbbrev  \
# 0  Portland Trail Blazers  Trail Blazers             7               DAL
# 1       Charlotte Hornets        Hornets             1               ATL
# 2         Houston Rockets        Rockets            10               GSW
# 3  Portland Trail Blazers  Trail Blazers             8               DEN
# 4             LA Clippers       Clippers            27               SAS
#
#   visitorTeamCity  visitorTeamConference visitorTeamDivision  \
# 0          Dallas                   West           Southwest
# 1         Atlanta                   East           Southeast
# 2    Golden State                   West             Pacific
# 3          Denver                   West           Northwest
# 4     San Antonio                   West           Southwest
#
#      visitorTeamFullName visitorTeamName
# 0       Dallas Mavericks       Mavericks
# 1          Atlanta Hawks           Hawks
# 2  Golden State Warriors        Warriors
# 3         Denver Nuggets         Nuggets
# 4      San Antonio Spurs           Spurs
#
# [5 rows x 23 columns]
